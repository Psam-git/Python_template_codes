# %%
from pandas import DataFrame, Series
import pandas as pd
import plotly.tools as tld
import plotly.plotly as py
py.sign_in('0819322','Z32pHRSy5HaCJ3nUprJX')
import cufflinks as cf

# %%
pd.DataFrame
DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
carsales = pd.read_csv('C:\Users\Student30\Documents\Used car data sets\cnt_km_year_powerPS_minPrice_maxPrice_avgPrice_sdPrice.csv')

# %%
carsales.head()
# Out:
#    count      km  year  powerPS  minPrice  maxPrice   avgPrice      sdPrice
# 0     19  125000  1991       40       300      1499   648.3158   352.035293
# 1     69  150000  1991       40       110      1600   516.4348   346.767661
# 2     11   90000  1991       60       330     10000  2342.4545  3017.432333
# 3     26  100000  1991       60       200      8750  1392.3846  1598.662833
# 4     42  125000  1991       60       150      4600  1140.6429  1010.314138

# %%
carsales.describe()  #data profiling
# Out:
#              count             km         year      powerPS      minPrice  \
# count  1770.000000    1770.000000  1770.000000  1770.000000   1770.000000
# mean    160.992655   88652.542373  2005.472316   152.011299   4161.532203
# std     378.592089   43909.507345     6.160430    80.359001   5492.165063
# min      11.000000    5000.000000  1991.000000    40.000000    101.000000
# 25%      20.000000   60000.000000  2001.000000    80.000000    350.000000
# 50%      47.000000   90000.000000  2007.000000   140.000000   1692.500000
# 75%     123.750000  125000.000000  2011.000000   200.000000   5999.750000
# max    3623.000000  150000.000000  2015.000000   520.000000  36675.000000
#
#            maxPrice      avgPrice       sdPrice
# count   1770.000000   1770.000000   1770.000000
# mean   21440.299435  10464.486905   3432.732575
# std    16356.444254   9219.917411   2878.065884
# min      950.000000    412.204500    193.395447
# 25%     8900.000000   3244.878600   1474.916671
# ...

# %%
csbyyear = carsales.groupby(['year','km']).mean()

# %%
csbyyear
# Out:
#                   count     powerPS      minPrice      maxPrice      avgPrice  \
# year km
# 1991 90000    11.666667   80.000000    293.333333   6233.000000   1772.207433
#      100000   17.666667   86.666667    240.000000   7543.333333   1978.772633
#      125000   28.400000   80.000000    319.800000   6419.800000   1676.628920
#      150000  138.846154  163.076923    702.076923  26053.846154   6236.907031
# 1992 80000    12.000000  100.000000    550.000000   6000.000000   2681.583300
#      90000    13.000000   70.000000    200.000000   1775.000000    760.230800
#      100000   15.000000   80.000000    250.000000   6783.000000   2217.337533
#      125000   27.666667   90.000000    315.000000   9949.833333   2350.169417
#      150000  154.000000  164.615385    587.615385  24073.076923   4483.878831
# 1993 80000    16.000000   80.000000    150.000000   3850.000000   1185.562500
#      90000    14.333333   80.000000    311.666667   2993.333333   1099.030900
# ...

# %%
! pip install cufflinks --upgrade
# Out:
# Requirement already up-to-date: cufflinks in c:\users\student30\anaconda3\lib\site-packages
# Requirement already up-to-date: plotly>=1.7.6 in c:\users\student30\anaconda3\lib\site-packages (from cufflinks)
# Requirement already up-to-date: colorlover>=0.2 in c:\users\student30\anaconda3\lib\site-packages (from cufflinks)
# Requirement already up-to-date: pandas in c:\users\student30\anaconda3\lib\site-packages (from cufflinks)
# Requirement already up-to-date: requests in c:\users\student30\anaconda3\lib\site-packages (from plotly>=1.7.6->cufflinks)
# Requirement already up-to-date: pytz in c:\users\student30\anaconda3\lib\site-packages (from plotly>=1.7.6->cufflinks)
# Requirement already up-to-date: six in c:\users\student30\anaconda3\lib\site-packages (from plotly>=1.7.6->cufflinks)
# Requirement already up-to-date: numpy>=1.7.0 in c:\users\student30\anaconda3\lib\site-packages (from pandas->cufflinks)
# ...

# %%
csbyyear.scatter_matrix()
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~0819322/0 or inside your plot.ly account where it is named 'Plotly Playground 2016-11-29 17:14:25'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~0819322/0.embed" height="525px" width="100%"></iframe>
