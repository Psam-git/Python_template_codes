# %%
casenumber=[]

# %%
import csv

with open(r"C:\Users\Student30\Documents\shark attack database\attacks.csv", "r") as orders:
 shreader = csv.reader(orders, delimiter=",",quotechar="#",skipinitialspace=True)
 shreader.next() #skips first line
 for s in shreader: #enumerate each row assigned to list w
  casenumber.append(s[1])
  print s
# Out:
# ['2016.09.18.c', '18-Sep-2016', '2016', 'Unprovoked', 'USA', 'Florida', '"New Smyrna Beach', 'Volusia County"', 'Surfing', 'male', 'M', '16', 'Minor injury to thigh', 'N', '13h00', '', '"Orlando Sentinel', '9/19/2016"']
# ['2016.09.18.b', '18-Sep-2016', '2016', 'Unprovoked', 'USA', 'Florida', '"New Smyrna Beach', 'Volusia County"', 'Surfing', 'Chucky Luciano', 'M', '36', 'Lacerations to hands', 'N', '11h00', '', '"Orlando Sentinel', '9/19/2016"']
# ['2016.09.18.a', '18-Sep-2016', '2016', 'Unprovoked', 'USA', 'Florida', '"New Smyrna Beach', 'Volusia County"', 'Surfing', 'male', 'M', '43', 'Lacerations to lower leg', 'N', '10h43', '', '"Orlando Sentinel', '9/19/2016"']
# ['2016.09.17', '17-Sep-2016', '2016', 'Unprovoked', 'AUSTRALIA', 'Victoria', 'Thirteenth Beach', 'Surfing', 'Rory Angiolella', 'M', '', 'Struck by fin on chest & leg', 'N', '', '', '"The Age', '9/18/2016"']
# ...

# %%
print casenumber
# Out:
# ['18-Sep-2016', '18-Sep-2016', '18-Sep-2016', '17-Sep-2016', '16-Sep-2016', '15-Sep-2016', '11-Sep-2016', '07-Sep-2016', '06-Sep-2016', '05-Sep-2016', '05-Sep-2016', '04-Sep-2016', '01-Sep-2016', '29-Aug-2016', '29-Aug-2016', '27-Aug-2016', '25-Aug-2016', '07-Aug-2016', '06-Aug-2016', '04-Aug-2016', '29-Jul-2016', '28-Jul-2016', '28-Jul-2016', '27-Jul-2016', '26-Jul-2016', '24-Jul-2016', '23-Jul-2016', '23-Jul-2016', '20-Jul-2016', '17-Jul-2016', '16-Jul-2016', '16-Jul-2016', '15-Jul-2016', 'Reported  14-Jul-2016', 'Reported 08-Jul-2016', '08-Jul-2016', '07-Jul-2016', '07-Jul-2016', '06-Jul-2016', '04-Jul-2016', '27-Jun-2016', '25-Jun-2016', '24-Jun-2016', '23-Jun-2016', '21-Jun-2016', '21-Jun-2016', '15-Jun-2016', '15-Jun-2016', '14-Jun-2016', '11-Jun-2016', '07-Jun-2016', '05-Jun-2016', '05-Jun-2016', '04-Jun-2016', '02-Jun-2016', '02-Jun-2016', '31-May-2016', '29-May-2016', 'F', '29-May-2016', '22-May-2016', '21-May-2016', '21-May-2016', '18-May-2016', '15-May-2016', '03-May-2016'
# ...
